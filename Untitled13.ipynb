# %% [markdown]
# <a href="https://colab.research.google.com/github/andresfelipebarragannino6-ai/Machine-Learning/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Cargar datos del club
datos_club = pd.read_csv('datos_club.csv')
datos_club.head()
# Out:
#   fecha_partido     equipo_local equipo_visitante  goles_local  \
# 0    2023-01-01  Atlético Python    Cebollitas FC            2
# 1    2023-01-08       NumPy City  Atlético Python            1
# 2    2023-01-15    Cebollitas FC      Data United            1
# 3    2023-01-22  Atlético Python      Data United            2
# 4    2023-01-29      Data United    Cebollitas FC            5
#
#    goles_visitante  posesion_local (%)  posesion_visitante (%)  \
# 0                0                  54                      46
# 1                5                  60                      40
# 2                0                  55                      45
# 3                3                  57                      43
# 4                3                  52                      48
#
#    tiros_arco_local  tiros_arco_visitante       estadio
# 0                12                     6  Python Arena
# 1                12                     3    Estadio ML
# 2                10                     7  Python Arena
# 3                 3                     3  Campo Pandas
# 4                 7                    12    Estadio ML

# %%
# Revisar información general
datos_club.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fecha_partido           100 non-null    object
#  1   equipo_local            100 non-null    object
#  2   equipo_visitante        100 non-null    object
#  3   goles_local             100 non-null    int64
#  4   goles_visitante         100 non-null    int64
#  5   posesion_local (%)      100 non-null    int64
#  6   posesion_visitante (%)  100 non-null    int64
#  7   tiros_arco_local        100 non-null    int64
#  8   tiros_arco_visitante    100 non-null    int64
#  9   estadio                 100 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 7.9+ KB

# %%
# Encontrar y manejar datos faltantes
datos_club.isnull().sum()
datos_club['goles_totales'] = datos_club['goles_local'].fillna(datos_club['goles_local'].mean())
print("Valores nulos antes de imputación")
print(datos_club.isnull().sum())
# Out:
# Valores nulos antes de imputación
# fecha_partido             0
# equipo_local              0
# equipo_visitante          0
# goles_local               0
# goles_visitante           0
# posesion_local (%)        0
# posesion_visitante (%)    0
# tiros_arco_local          0
# tiros_arco_visitante      0
# estadio                   0
# goles_totales             0
# dtype: int64

# %%
# One-Hot Enconig para equipos
datos_preparados = pd.get_dummies(datos_club, columns=['equipo_local', 'equipo_visitante']) # La función get_dummies convierte los equipos en columnas binarias
datos_preparados.head()
# Out:
#   fecha_partido  goles_local  goles_visitante  posesion_local (%)  \
# 0    2023-01-01            2                0                  54
# 1    2023-01-08            1                5                  60
# 2    2023-01-15            1                0                  55
# 3    2023-01-22            2                3                  57
# 4    2023-01-29            5                3                  52
#
#    posesion_visitante (%)  tiros_arco_local  tiros_arco_visitante  \
# 0                      46                12                     6
# 1                      40                12                     3
# 2                      45                10                     7
# 3                      43                 3                     3
# 4                      48                 7                    12
#
#         estadio  goles_totales  equipo_local_Atlético Python  \
# 0  Python Arena              2                          True
# 1    Estadio ML              1                         False
# 2  Python Arena              1                         False
# 3  Campo Pandas              2                          True
# 4    Estadio ML              5                         False
#
#    equipo_local_Cebollitas FC  equipo_local_Data United  \
# 0                       False                     False
# 1                       False                     False
# 2                        True                     False
# 3                       False                     False
# 4                       False                      True
#
#    equipo_local_NumPy City  equipo_local_Real Pandas  \
# 0                    False                     False
# 1                     True                     False
# 2                    False                     False
# 3                    False                     False
# 4                    False                     False
#
#    equipo_visitante_Atlético Python  equipo_visitante_Cebollitas FC  \
# 0                             False                            True
# 1                              True                           False
# 2                             False                           False
# 3                             False                           False
# 4                             False                            True
#
#    equipo_visitante_Data United  equipo_visitante_NumPy City  \
# 0                         False                        False
# 1                         False                        False
# 2                          True                        False
# 3                          True                        False
# 4                         False                        False
#
#    equipo_visitante_Real Pandas
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False

# %%
# Eliminar filas duplicadas
datos_preparados.drop_duplicates(inplace=True)

print(f'Filas antes de eliminar duplicados:',len(datos_preparados))
datos_preparados.drop_duplicates(inplace=True)
print(f'Filas después de eliminar duplicados:',len(datos_preparados))
# Out:
# Filas antes de eliminar duplicados: 100
# Filas después de eliminar duplicados: 100

# %%
# Manejar Fechas
datos_preparados['fecha_partido'] = pd.to_datetime(datos_preparados['fecha_partido'],errors='coerce')
print("Fechas invalidas (Nat) luego de la conversión")
print(datos_preparados['fecha_partido'].isnull().sum())
# Out:
# Fechas invalidas (Nat) luego de la conversión
# 0

# %%
print(datos_preparados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   fecha_partido                     100 non-null    datetime64[ns]
#  1   goles_local                       100 non-null    int64
#  2   goles_visitante                   100 non-null    int64
#  3   posesion_local (%)                100 non-null    int64
#  4   posesion_visitante (%)            100 non-null    int64
#  5   tiros_arco_local                  100 non-null    int64
#  6   tiros_arco_visitante              100 non-null    int64
#  7   estadio                           100 non-null    object
#  8   goles_totales                     100 non-null    int64
#  9   equipo_local_Atlético Python      100 non-null    bool
#  10  equipo_local_Cebollitas FC        100 non-null    bool
#  11  equipo_local_Data United          100 non-null    bool
#  12  equipo_local_NumPy City           100 non-null    bool
#  13  equipo_local_Real Pandas          100 non-null    bool
#  14  equipo_visitante_Atlético Python  100 non-null    bool
#  15  equipo_visitante_Cebollitas FC    100 non-null    bool
#  16  equipo_visitante_Data United      100 non-null    bool
#  17  equipo_visitante_NumPy City       100 non-null    bool
#  18  equipo_visitante_Real Pandas      100 non-null    bool
# dtypes: bool(10), datetime64[ns](1), int64(7), object(1)
# memory usage: 8.1+ KB
# None

# %%
print("Columnas con valores nulos tras limpieza:")
print(datos_preparados.isnull().sum())
# Out:
# Columnas con valores nulos tras limpieza:
# fecha_partido                       0
# goles_local                         0
# goles_visitante                     0
# posesion_local (%)                  0
# posesion_visitante (%)              0
# tiros_arco_local                    0
# tiros_arco_visitante                0
# estadio                             0
# goles_totales                       0
# equipo_local_Atlético Python        0
# equipo_local_Cebollitas FC          0
# equipo_local_Data United            0
# equipo_local_NumPy City             0
# equipo_local_Real Pandas            0
# equipo_visitante_Atlético Python    0
# equipo_visitante_Cebollitas FC      0
# equipo_visitante_Data United        0
# equipo_visitante_NumPy City         0
# equipo_visitante_Real Pandas        0
# dtype: int64

# %%
print("Vista final del dataset final:")
display(datos_preparados.head())
# Out:
# Vista final del dataset final:
#   fecha_partido  goles_local  goles_visitante  posesion_local (%)  \
# 0    2023-01-01            2                0                  54
# 1    2023-01-08            1                5                  60
# 2    2023-01-15            1                0                  55
# 3    2023-01-22            2                3                  57
# 4    2023-01-29            5                3                  52
#
#    posesion_visitante (%)  tiros_arco_local  tiros_arco_visitante  \
# 0                      46                12                     6
# 1                      40                12                     3
# 2                      45                10                     7
# 3                      43                 3                     3
# 4                      48                 7                    12
#
#         estadio  goles_totales  equipo_local_Atlético Python  \
# 0  Python Arena              2                          True
# 1    Estadio ML              1                         False
# 2  Python Arena              1                         False
# 3  Campo Pandas              2                          True
# 4    Estadio ML              5                         False
#
#    equipo_local_Cebollitas FC  equipo_local_Data United  \
# 0                       False                     False
# 1                       False                     False
# 2                        True                     False
# 3                       False                     False
# 4                       False                      True
#
#    equipo_local_NumPy City  equipo_local_Real Pandas  \
# 0                    False                     False
# 1                     True                     False
# 2                    False                     False
# 3                    False                     False
# 4                    False                     False
#
#    equipo_visitante_Atlético Python  equipo_visitante_Cebollitas FC  \
# 0                             False                            True
# 1                              True                           False
# 2                             False                           False
# 3                             False                           False
# 4                             False                            True
#
#    equipo_visitante_Data United  equipo_visitante_NumPy City  \
# 0                         False                        False
# 1                         False                        False
# 2                          True                        False
# 3                          True                        False
# 4                         False                        False
#
#    equipo_visitante_Real Pandas
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
